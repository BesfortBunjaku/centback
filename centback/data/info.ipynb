# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\besff\OneDrive\Documents\GitHub\centback\centback\data\europade.csv')
df
# Out:
#                                                  url  \
# 0  https://ec.europa.eu/eures/eures-apps/searchen...
#
#                                                 data  \
# 0  {'keywords': [{'keyword': 'kurier', 'specificS...
#
#                                              headers  \
# 0  {'Accept': 'application/json, text/plain, */*'...
#
#                                             icontent  \
# 0  {'id': 'MTAwMDAtMTE5NTQ0ODk4MS1TIDE', 'creatio...
#
#                                         job_title_de           company_name  \
# 0  Zusteller/in - Post (m/w/d) (Fachkraft - Kurie...  Falcon Transport GmbH
#
#                                         job_title_en  \
# 0  Zusteller/in - Post (m/w/d) (Fachkraft - Kurie...
#
#                                           source_url  \
# 0  https://ec.europa.eu/eures/portal/jv-se/jv-det...
#
#                                          jsource_url  \
# 0  https://ec.europa.eu/eures/eures-apps/searchen...
#
# ...
